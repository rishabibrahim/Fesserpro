# %%
# indexing and slicing
name="banknifty"
c1=len(name)//2
name[c1:]
name[:c1]
# Out:
# 'bank'

# %%
# example with a link- slicing name from the website
# index function
link="https://www.google.com/"
link.index(".")
# Out:
# 11

# %%
link.index(".com")
# Out:
# 18

# %%
link[12:18]
# Out:
# 'google'

# %%
# Replace function
a="nifty50"
a.replace("50","60")
# Out:
# 'nifty60'

# %%
# problem
# we need to convert this number to 398.468
number=468.398
# convert float value to string
string=str(number) 
string.index(".")
output=float(string[4:]+string[3]+string[:3])
output
# Out:
# 398.468

# %%
# above is my approach for the problem this is sunils method , which is dynamic.
i=string.index(".")
start=string[:i]
end=string[i+1:]
end_result=float(end+"."+start)
end_result
# Out:
# 398.468

# %%
#  other functions
# upper
# lower
# capitalize
# count
# strip

# %%
# Slicing - the last 2 indicates the skip
"relaince"[0:7:2]
# Out:
# 'rlic'
